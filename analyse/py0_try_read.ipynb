# %%
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('../saved/neural_data_right_ALM_57_opt1.pkl', 'rb') as f:
    results = pkl.load(f)

# %%
trial = 40
Phi1 = -np.log(results['peq'][trial][0]) 
plt.plot(Phi1)

# %%
trial = 0
neuron = 0
plt.plot(results['fr'][trial][0][:,neuron])

# %%
D_list = [d[0] for d in results['D']]
plt.plot(D_list)

# %%
plt.plot(results['logliks'][0])
